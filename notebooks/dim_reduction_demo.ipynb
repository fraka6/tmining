# %% [markdown]
# # Simple example -> dimention reduction
# # Leveraging matplotlib + scikit-learn (mlboost)

# %%
# %pylab inline
# %matplotlib inline
import mlboost
from mlboost.clustering.visu import main as visu
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
visu('-m pca')
# Out:
# loading data.tsv
# Loading 20 newsgroups dataset for categories:
# ['alt.atheism', 'talk.religion.misc', 'comp.graphics', 'sci.space']
# data loaded
# 4 categories
# ()
# 2034 documents - 3.980MB (training set)
# 1353 documents - 2.867MB (test set)
# Extracting features from the training dataset using a sparse vectorizer
# done in 1.179468s at 3.374MB/s
# n_samples: 2034, n_features: 33810
# ()
# Extracting features from the test dataset using the same vectorizer
# done in 0.684141s at 4.191MB/s
# n_samples: 1353, n_features: 33810
# ()
# data shape: (2034,33810)
# Computing PCA projection
# Projecting pca on test set
# Rendering plot Principal Components projection (time 5.20s)
# saving news_pca.png

# %%
from mlboost.clustering.dim_reduction import fct_available
print fct_available()
# Out:
# ['hlle', 'lda', 'pca', 'mlle', 'tsne', 'random', 'ltsa', 'isomap', 'lle', 'rtree']
